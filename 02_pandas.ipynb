# %%
'''
CLASS: Pandas for Data Exploration, Analysis, and Visualization

WHO alcohol consumption data:
    article: http://fivethirtyeight.com/datalab/dear-mona-followup-where-do-people-drink-the-most-beer-wine-and-spirits/    
    original data: https://github.com/fivethirtyeight/data/tree/master/alcohol-consumption
    files: drinks.csv (with additional 'continent' column)
'''
# Out:
# "\nCLASS: Pandas for Data Exploration, Analysis, and Visualization\n\nWHO alcohol consumption data:\n    article: http://fivethirtyeight.com/datalab/dear-mona-followup-where-do-people-drink-the-most-beer-wine-and-spirits/    \n    original data: https://github.com/fivethirtyeight/data/tree/master/alcohol-consumption\n    files: drinks.csv (with additional 'continent' column)\n"

# %%
# imports
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
plt.style.use('ggplot')
# %matplotlib inline

# %%
'''
Pandas Basics: Reading Files, Summarizing, Handling Missing Values, Filtering, Sorting
'''

# read in the CSV file from a URL
drinks = pd.read_csv('../data/drinks.csv')

type(drinks)            # Use the type method to check python type
# Out:
# pandas.core.frame.DataFrame

# %%
# examine the data
drinks                  # print the first 30 and last 30 rows
# Out:
#                   country  beer_servings  spirit_servings  wine_servings  \
# 0             Afghanistan              0                0              0
# 1                 Albania             89              132             54
# 2                 Algeria             25                0             14
# 3                 Andorra            245              138            312
# 4                  Angola            217               57             45
# 5       Antigua & Barbuda            102              128             45
# 6               Argentina            193               25            221
# 7                 Armenia             21              179             11
# 8               Australia            261               72            212
# 9                 Austria            279               75            191
# 10             Azerbaijan             21               46              5
# 11                Bahamas            122              176             51
# 12                Bahrain             42               63              7
# 13             Bangladesh              0                0              0
# 14               Barbados            143              173             36
# 15                Belarus            142              373             42
# 16                Belgium            295               84            212
# 17                 Belize            263              114              8
# 18                  Benin             34                4             13
# 19                 Bhutan             23                0              0
# 20                Bolivia            167               41              8
# 21     Bosnia-Herzegovina             76              173              8
# 22               Botswana            173               35             35
# 23                 Brazil            245              145             16
# 24                 Brunei             31                2              1
# 25               Bulgaria            231              252             94
# 26           Burkina Faso             25                7              7
# 27                Burundi             88                0              0
# 28          Cote d'Ivoire             37                1              7
# 29             Cabo Verde            144               56             16
# ..                    ...            ...              ...            ...
# 163              Suriname            128              178              7
# 164             Swaziland             90                2              2
# 165                Sweden            152               60            186
# 166           Switzerland            185              100            280
# 167                 Syria              5               35             16
# 168            Tajikistan              2               15              0
# 169              Thailand             99              258              1
# 170             Macedonia            106               27             86
# 171           Timor-Leste              1                1              4
# 172                  Togo             36                2             19
# 173                 Tonga             36               21              5
# 174     Trinidad & Tobago            197              156              7
# 175               Tunisia             51                3             20
# 176                Turkey             51               22              7
# 177          Turkmenistan             19               71             32
# 178                Tuvalu              6               41              9
# 179                Uganda             45                9              0
# 180               Ukraine            206              237             45
# 181  United Arab Emirates             16              135              5
# 182        United Kingdom            219              126            195
# 183              Tanzania             36                6              1
# 184                   USA            249              158             84
# 185               Uruguay            115               35            220
# 186            Uzbekistan             25              101              8
# 187               Vanuatu             21               18             11
# 188             Venezuela            333              100              3
# 189               Vietnam            111                2              1
# 190                 Yemen              6                0              0
# 191                Zambia             32               19              4
# 192              Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol continent
# 0                             0.0        AS
# 1                             4.9        EU
# 2                             0.7        AF
# 3                            12.4        EU
# 4                             5.9        AF
# 5                             4.9       NaN
# 6                             8.3        SA
# 7                             3.8        EU
# 8                            10.4        OC
# 9                             9.7        EU
# 10                            1.3        EU
# 11                            6.3       NaN
# 12                            2.0        AS
# 13                            0.0        AS
# 14                            6.3       NaN
# 15                           14.4        EU
# 16                           10.5        EU
# 17                            6.8       NaN
# 18                            1.1        AF
# 19                            0.4        AS
# 20                            3.8        SA
# 21                            4.6        EU
# 22                            5.4        AF
# 23                            7.2        SA
# 24                            0.6        AS
# 25                           10.3        EU
# 26                            4.3        AF
# 27                            6.3        AF
# 28                            4.0        AF
# 29                            4.0        AF
# ..                            ...       ...
# 163                           5.6        SA
# 164                           4.7        AF
# 165                           7.2        EU
# 166                          10.2        EU
# 167                           1.0        AS
# 168                           0.3        AS
# 169                           6.4        AS
# 170                           3.9        EU
# 171                           0.1        AS
# 172                           1.3        AF
# 173                           1.1        OC
# 174                           6.4       NaN
# 175                           1.3        AF
# 176                           1.4        AS
# 177                           2.2        AS
# 178                           1.0        OC
# 179                           8.3        AF
# 180                           8.9        EU
# 181                           2.8        AS
# 182                          10.4        EU
# 183                           5.7        AF
# 184                           8.7       NaN
# 185                           6.6        SA
# 186                           2.4        AS
# 187                           0.9        OC
# 188                           7.7        SA
# 189                           2.0        AS
# 190                           0.1        AS
# 191                           2.5        AF
# 192                           4.7        AF
#
# [193 rows x 6 columns]

# %%
drinks.head()           # print the first 5 rows
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0        AS
# 1                           4.9        EU
# 2                           0.7        AF
# 3                          12.4        EU
# 4                           5.9        AF

# %%
drinks.tail()           # print the last 5 rows
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 188  Venezuela            333              100              3
# 189    Vietnam            111                2              1
# 190      Yemen              6                0              0
# 191     Zambia             32               19              4
# 192   Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol continent
# 188                           7.7        SA
# 189                           2.0        AS
# 190                           0.1        AS
# 191                           2.5        AF
# 192                           4.7        AF

# %%
drinks.describe()       # describe any numeric columns
# Out:
#        beer_servings  spirit_servings  wine_servings  \
# count     193.000000       193.000000     193.000000
# mean      106.160622        80.994819      49.450777
# std       101.143103        88.284312      79.697598
# min         0.000000         0.000000       0.000000
# 25%        20.000000         4.000000       1.000000
# 50%        76.000000        56.000000       8.000000
# 75%       188.000000       128.000000      59.000000
# max       376.000000       438.000000     370.000000
#
#        total_litres_of_pure_alcohol
# count                    193.000000
# mean                       4.717098
# std                        3.773298
# min                        0.000000
# 25%                        1.300000
# 50%                        4.200000
# 75%                        7.200000
# max                       14.400000

# %%
drinks.columns          # get series of column names
# Out:
# Index([u'country', u'beer_servings', u'spirit_servings', u'wine_servings',
#        u'total_litres_of_pure_alcohol', u'continent'],
#       dtype='object')

# %%
# Note: the dataframe is like a more complicated dictionary where the 
# column names are the keys and the column itself is the value

d = {'a':[1,2], 'b':[3,4]}
pd.DataFrame(d)
# Out:
#    a  b
# 0  1  3
# 1  2  4

# %%
drinks.shape            # tuple of (#rows, #cols)
# Out:
# (193, 6)

# %%
# find missing values in a DataFrame
drinks.isnull()         # DataFrame of booleans
drinks.isnull().sum()   # convert booleans to integers and add
# Out:
# country                          0
# beer_servings                    0
# spirit_servings                  0
# wine_servings                    0
# total_litres_of_pure_alcohol     0
# continent                       23
# dtype: int64

# %%
# So we have 23 missing continent values, that's a no bueno situation

''' SELECT * from drinks where continent is NULL '''
drinks[drinks['continent'].isnull()]         # DataFrame of values with null continent value

# Anyone have any thoughts?
# Out:
#                           country  beer_servings  spirit_servings  \
# 5               Antigua & Barbuda            102              128
# 11                        Bahamas            122              176
# 14                       Barbados            143              173
# 17                         Belize            263              114
# 32                         Canada            240              122
# 41                     Costa Rica            149               87
# 43                           Cuba             93              137
# 50                       Dominica             52              286
# 51             Dominican Republic            193              147
# 54                    El Salvador             52               69
# 68                        Grenada            199              438
# 69                      Guatemala             53               69
# 73                          Haiti              1              326
# 74                       Honduras             69               98
# 84                        Jamaica             82               97
# 109                        Mexico            238               68
# 122                     Nicaragua             78              118
# 130                        Panama            285              104
# 143             St. Kitts & Nevis            194              205
# 144                     St. Lucia            171              315
# 145  St. Vincent & the Grenadines            120              221
# 174             Trinidad & Tobago            197              156
# 184                           USA            249              158
#
#      wine_servings  total_litres_of_pure_alcohol continent
# 5               45                           4.9       NaN
# 11              51                           6.3       NaN
# 14              36                           6.3       NaN
# 17               8                           6.8       NaN
# 32             100                           8.2       NaN
# 41              11                           4.4       NaN
# 43               5                           4.2       NaN
# 50              26                           6.6       NaN
# 51               9                           6.2       NaN
# 54               2                           2.2       NaN
# 68              28                          11.9       NaN
# 69               2                           2.2       NaN
# 73               1                           5.9       NaN
# 74               2                           3.0       NaN
# 84               9                           3.4       NaN
# 109              5                           5.5       NaN
# 122              1                           3.5       NaN
# 130             18                           7.2       NaN
# 143             32                           7.7       NaN
# 144             71                          10.1       NaN
# 145             11                           6.3       NaN
# 174              7                           6.4       NaN
# 184             84                           8.7       NaN

# %%
# Pandas isn't brilliant, it saw the "NA" string and assumed it meant a null value

# handling missing values
drinks.dropna()             # drop a row if ANY values are missing
drinks.fillna(value='NA')   # fill in missing values
# Out:
#                   country  beer_servings  spirit_servings  wine_servings  \
# 0             Afghanistan              0                0              0
# 1                 Albania             89              132             54
# 2                 Algeria             25                0             14
# 3                 Andorra            245              138            312
# 4                  Angola            217               57             45
# 5       Antigua & Barbuda            102              128             45
# 6               Argentina            193               25            221
# 7                 Armenia             21              179             11
# 8               Australia            261               72            212
# 9                 Austria            279               75            191
# 10             Azerbaijan             21               46              5
# 11                Bahamas            122              176             51
# 12                Bahrain             42               63              7
# 13             Bangladesh              0                0              0
# 14               Barbados            143              173             36
# 15                Belarus            142              373             42
# 16                Belgium            295               84            212
# 17                 Belize            263              114              8
# 18                  Benin             34                4             13
# 19                 Bhutan             23                0              0
# 20                Bolivia            167               41              8
# 21     Bosnia-Herzegovina             76              173              8
# 22               Botswana            173               35             35
# 23                 Brazil            245              145             16
# 24                 Brunei             31                2              1
# 25               Bulgaria            231              252             94
# 26           Burkina Faso             25                7              7
# 27                Burundi             88                0              0
# 28          Cote d'Ivoire             37                1              7
# 29             Cabo Verde            144               56             16
# ..                    ...            ...              ...            ...
# 163              Suriname            128              178              7
# 164             Swaziland             90                2              2
# 165                Sweden            152               60            186
# 166           Switzerland            185              100            280
# 167                 Syria              5               35             16
# 168            Tajikistan              2               15              0
# 169              Thailand             99              258              1
# 170             Macedonia            106               27             86
# 171           Timor-Leste              1                1              4
# 172                  Togo             36                2             19
# 173                 Tonga             36               21              5
# 174     Trinidad & Tobago            197              156              7
# 175               Tunisia             51                3             20
# 176                Turkey             51               22              7
# 177          Turkmenistan             19               71             32
# 178                Tuvalu              6               41              9
# 179                Uganda             45                9              0
# 180               Ukraine            206              237             45
# 181  United Arab Emirates             16              135              5
# 182        United Kingdom            219              126            195
# 183              Tanzania             36                6              1
# 184                   USA            249              158             84
# 185               Uruguay            115               35            220
# 186            Uzbekistan             25              101              8
# 187               Vanuatu             21               18             11
# 188             Venezuela            333              100              3
# 189               Vietnam            111                2              1
# 190                 Yemen              6                0              0
# 191                Zambia             32               19              4
# 192              Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol continent
# 0                             0.0        AS
# 1                             4.9        EU
# 2                             0.7        AF
# 3                            12.4        EU
# 4                             5.9        AF
# 5                             4.9        NA
# 6                             8.3        SA
# 7                             3.8        EU
# 8                            10.4        OC
# 9                             9.7        EU
# 10                            1.3        EU
# 11                            6.3        NA
# 12                            2.0        AS
# 13                            0.0        AS
# 14                            6.3        NA
# 15                           14.4        EU
# 16                           10.5        EU
# 17                            6.8        NA
# 18                            1.1        AF
# 19                            0.4        AS
# 20                            3.8        SA
# 21                            4.6        EU
# 22                            5.4        AF
# 23                            7.2        SA
# 24                            0.6        AS
# 25                           10.3        EU
# 26                            4.3        AF
# 27                            6.3        AF
# 28                            4.0        AF
# 29                            4.0        AF
# ..                            ...       ...
# 163                           5.6        SA
# 164                           4.7        AF
# 165                           7.2        EU
# 166                          10.2        EU
# 167                           1.0        AS
# 168                           0.3        AS
# 169                           6.4        AS
# 170                           3.9        EU
# 171                           0.1        AS
# 172                           1.3        AF
# 173                           1.1        OC
# 174                           6.4        NA
# 175                           1.3        AF
# 176                           1.4        AS
# 177                           2.2        AS
# 178                           1.0        OC
# 179                           8.3        AF
# 180                           8.9        EU
# 181                           2.8        AS
# 182                          10.4        EU
# 183                           5.7        AF
# 184                           8.7        NA
# 185                           6.6        SA
# 186                           2.4        AS
# 187                           0.9        OC
# 188                           7.7        SA
# 189                           2.0        AS
# 190                           0.1        AS
# 191                           2.5        AF
# 192                           4.7        AF
#
# [193 rows x 6 columns]

# %%
# fix the original import, this time using a live url!
drinks = pd.read_csv('https://raw.githubusercontent.com/sinanuozdemir/sfdat26/master/data/drinks.csv', na_filter=False)
drinks.isnull().sum()
# Out:
# country                         0
# beer_servings                   0
# spirit_servings                 0
# wine_servings                   0
# total_litres_of_pure_alcohol    0
# continent                       0
# dtype: int64

# %%
# selecting a column ('Series')
drinks['continent']
drinks.continent            # equivalent

# Note the dictionary like selection
# Out:
# 0      AS
# 1      EU
# 2      AF
# 3      EU
# 4      AF
# 5      NA
# 6      SA
# 7      EU
# 8      OC
# 9      EU
# 10     EU
# 11     NA
# 12     AS
# 13     AS
# 14     NA
# 15     EU
# 16     EU
# 17     NA
# 18     AF
# 19     AS
# 20     SA
# 21     EU
# 22     AF
# 23     SA
# 24     AS
# 25     EU
# 26     AF
# 27     AF
# 28     AF
# 29     AF
#        ..
# 163    SA
# 164    AF
# 165    EU
# 166    EU
# 167    AS
# 168    AS
# 169    AS
# 170    EU
# 171    AS
# 172    AF
# 173    OC
# 174    NA
# 175    AF
# 176    AS
# 177    AS
# 178    OC
# 179    AF
# 180    EU
# 181    AS
# 182    EU
# 183    AF
# 184    NA
# 185    SA
# 186    AS
# 187    OC
# 188    SA
# 189    AS
# 190    AS
# 191    AF
# 192    AF
# Name: continent, dtype: object

# %%
type(drinks.continent)      # Series if pandas equivalent to list
# Out:
# pandas.core.series.Series

# %%
# summarizing a non-numeric column
drinks.continent.describe()
# Out:
# count     193
# unique      6
# top        AF
# freq       53
# Name: continent, dtype: object

# %%
drinks.continent.value_counts()
# Out:
# AF    53
# EU    45
# AS    44
# NA    23
# OC    16
# SA    12
# Name: continent, dtype: int64

# %%
'''
note the double square bracket
the outer pair is used like in a python dictionary
    to select
the inner pair is a list!

so in all, the double use of square brackets is telling
the dataframe to select a list!
'''
# selecting multiple columns
''' SELECT country,beer_servings FROM drinks '''
drinks[['country', 'beer_servings']].head()


# remember the .head() just shows us the first 5 rows
# Out:
#        country  beer_servings
# 0  Afghanistan              0
# 1      Albania             89
# 2      Algeria             25
# 3      Andorra            245
# 4       Angola            217

# %%
my_cols = ['country', 'beer_servings']
drinks[my_cols].head()
# Out:
#        country  beer_servings
# 0  Afghanistan              0
# 1      Albania             89
# 2      Algeria             25
# 3      Andorra            245
# 4       Angola            217

# %%
# add a new column as a function of existing columns
drinks['total_servings'] = drinks.beer_servings + drinks.spirit_servings + drinks.wine_servings
drinks['beer_pct_total'] = drinks.beer_servings/drinks.total_servings

drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent  total_servings  beer_pct_total
# 0                           0.0        AS               0             NaN
# 1                           4.9        EU             275        0.323636
# 2                           0.7        AF              39        0.641026
# 3                          12.4        EU             695        0.352518
# 4                           5.9        AF             319        0.680251

# %%
# logical filtering and sorting

'''
How it works:
    drinks.continent=='EU' by itself returns a bunch
        of Trues and Falses
        
drinks.continent=='EU'

See?


when you wrap drinks around it with square brackets
you're telling the drinks dataframe to select
only those that are True, and not the False ones

drinks[drinks.continent=='EU']
'''
drinks.continent=='EU' # this is a series of T and F

# we put tht series of Trues and Falses directly into the square brackets of justice
drinks[drinks.continent=='EU'] .head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 1      Albania             89              132             54
# 3      Andorra            245              138            312
# 7      Armenia             21              179             11
# 9      Austria            279               75            191
# 10  Azerbaijan             21               46              5
#
#     total_litres_of_pure_alcohol continent  total_servings  beer_pct_total
# 1                            4.9        EU             275        0.323636
# 3                           12.4        EU             695        0.352518
# 7                            3.8        EU             211        0.099526
# 9                            9.7        EU             545        0.511927
# 10                           1.3        EU              72        0.291667

# %%
# North American countries with total servings
# drinks[['country', 'total_servings']][drinks.continent=='NA']

new_df = drinks[['country', 'total_servings','beer_pct_total']] # selection of two columns
new_df[drinks.continent=='NA']
# Out:
#                           country  total_servings  beer_pct_total
# 5               Antigua & Barbuda             275        0.370909
# 11                        Bahamas             349        0.349570
# 14                       Barbados             352        0.406250
# 17                         Belize             385        0.683117
# 32                         Canada             462        0.519481
# 41                     Costa Rica             247        0.603239
# 43                           Cuba             235        0.395745
# 50                       Dominica             364        0.142857
# 51             Dominican Republic             349        0.553009
# 54                    El Salvador             123        0.422764
# 68                        Grenada             665        0.299248
# 69                      Guatemala             124        0.427419
# 73                          Haiti             328        0.003049
# 74                       Honduras             169        0.408284
# 84                        Jamaica             188        0.436170
# 109                        Mexico             311        0.765273
# 122                     Nicaragua             197        0.395939
# 130                        Panama             407        0.700246
# 143             St. Kitts & Nevis             431        0.450116
# 144                     St. Lucia             557        0.307002
# 145  St. Vincent & the Grenadines             352        0.340909
# 174             Trinidad & Tobago             360        0.547222
# 184                           USA             491        0.507128

# %%
# same thing, sorted by total_servings
drinks[['country', 'total_servings','beer_pct_total']][drinks.continent=='NA'].sort_index(by='beer_pct_total')
# Out:
# /Users/Varun/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:2: FutureWarning: by argument to sort_index is deprecated, pls use .sort_values(by=...)
#   from ipykernel import kernelapp as app
#                           country  total_servings  beer_pct_total
# 73                          Haiti             328        0.003049
# 50                       Dominica             364        0.142857
# 68                        Grenada             665        0.299248
# 144                     St. Lucia             557        0.307002
# 145  St. Vincent & the Grenadines             352        0.340909
# 11                        Bahamas             349        0.349570
# 5               Antigua & Barbuda             275        0.370909
# 43                           Cuba             235        0.395745
# 122                     Nicaragua             197        0.395939
# 14                       Barbados             352        0.406250
# 74                       Honduras             169        0.408284
# 54                    El Salvador             123        0.422764
# 69                      Guatemala             124        0.427419
# 84                        Jamaica             188        0.436170
# 143             St. Kitts & Nevis             431        0.450116
# 184                           USA             491        0.507128
# 32                         Canada             462        0.519481
# 174             Trinidad & Tobago             360        0.547222
# 51             Dominican Republic             349        0.553009
# 41                     Costa Rica             247        0.603239
# 17                         Belize             385        0.683117
# 130                        Panama             407        0.700246
# 109                        Mexico             311        0.765273

# %%
#sorted in reverse order
drinks[['country', 'total_servings','beer_pct_total']][drinks.continent=='NA'].sort_index(by='beer_pct_total', ascending = False)
# Out:
# /Users/Varun/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:2: FutureWarning: by argument to sort_index is deprecated, pls use .sort_values(by=...)
#   from ipykernel import kernelapp as app
#                           country  total_servings  beer_pct_total
# 109                        Mexico             311        0.765273
# 130                        Panama             407        0.700246
# 17                         Belize             385        0.683117
# 41                     Costa Rica             247        0.603239
# 51             Dominican Republic             349        0.553009
# 174             Trinidad & Tobago             360        0.547222
# 32                         Canada             462        0.519481
# 184                           USA             491        0.507128
# 143             St. Kitts & Nevis             431        0.450116
# 84                        Jamaica             188        0.436170
# 69                      Guatemala             124        0.427419
# 54                    El Salvador             123        0.422764
# 74                       Honduras             169        0.408284
# 14                       Barbados             352        0.406250
# 122                     Nicaragua             197        0.395939
# 43                           Cuba             235        0.395745
# 5               Antigua & Barbuda             275        0.370909
# 11                        Bahamas             349        0.349570
# 145  St. Vincent & the Grenadines             352        0.340909
# 144                     St. Lucia             557        0.307002
# 68                        Grenada             665        0.299248
# 50                       Dominica             364        0.142857
# 73                          Haiti             328        0.003049

# %%
# contries with wine servings over 300 and total liters over 12
drinks[drinks.wine_servings > 300][drinks.total_litres_of_pure_alcohol > 12]
# Out:
# /Users/Varun/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   from ipykernel import kernelapp as app
#    country  beer_servings  spirit_servings  wine_servings  \
# 3  Andorra            245              138            312
#
#    total_litres_of_pure_alcohol continent  total_servings  beer_pct_total
# 3                          12.4        EU             695        0.352518

# %%
# Same result but using python logic operators
# Note the paranthesis around each filter when using logical operators
drinks[(drinks.wine_servings > 300) & (drinks.total_litres_of_pure_alcohol > 12)]
# Out:
#    country  beer_servings  spirit_servings  wine_servings  \
# 3  Andorra            245              138            312
#
#    total_litres_of_pure_alcohol continent  total_servings  beer_pct_total
# 3                          12.4        EU             695        0.352518

# %%
# contries with more wine servings than beer servings
drinks[drinks.wine_servings > drinks.beer_servings]
# Out:
#                  country  beer_servings  spirit_servings  wine_servings  \
# 3                Andorra            245              138            312
# 6              Argentina            193               25            221
# 35                 Chile            130              124            172
# 40          Cook Islands              0              254             74
# 42               Croatia            230               87            254
# 48               Denmark            224               81            278
# 55     Equatorial Guinea             92                0            233
# 61                France            127              151            370
# 64               Georgia             52              100            149
# 67                Greece            133              112            218
# 83                 Italy             85               42            237
# 92                  Laos             62                0            123
# 94               Lebanon             20               55             31
# 99            Luxembourg            236              133            271
# 113           Montenegro             31              114            128
# 136             Portugal            194               67            339
# 137                Qatar              1               42              7
# 148  Sao Tome & Principe             56               38            140
# 156             Slovenia            270               51            276
# 165               Sweden            152               60            186
# 166          Switzerland            185              100            280
# 167                Syria              5               35             16
# 171          Timor-Leste              1                1              4
# 177         Turkmenistan             19               71             32
# 178               Tuvalu              6               41              9
# 185              Uruguay            115               35            220
#
#      total_litres_of_pure_alcohol continent  total_servings  beer_pct_total
# 3                            12.4        EU             695        0.352518
# 6                             8.3        SA             439        0.439636
# 35                            7.6        SA             426        0.305164
# 40                            5.9        OC             328        0.000000
# 42                           10.2        EU             571        0.402802
# 48                           10.4        EU             583        0.384220
# 55                            5.8        AF             325        0.283077
# 61                           11.8        EU             648        0.195988
# 64                            5.4        EU             301        0.172757
# 67                            8.3        EU             463        0.287257
# 83                            6.5        EU             364        0.233516
# 92                            6.2        AS             185        0.335135
# 94                            1.9        AS             106        0.188679
# 99                           11.4        EU             640        0.368750
# 113                           4.9        EU             273        0.113553
# 136                          11.0        EU             600        0.323333
# 137                           0.9        AS              50        0.020000
# 148                           4.2        AF             234        0.239316
# 156                          10.6        EU             597        0.452261
# 165                           7.2        EU             398        0.381910
# 166                          10.2        EU             565        0.327434
# 167                           1.0        AS              56        0.089286
# 171                           0.1        AS               6        0.166667
# 177                           2.2        AS             122        0.155738
# 178                           1.0        OC              56        0.107143
# 185                           6.6        SA             370        0.310811

# %%
# to reiterate how the filter works:
drinks.wine_servings > drinks.beer_servings # is a series of T and F
# Out:
# 0      False
# 1      False
# 2      False
# 3       True
# 4      False
# 5      False
# 6       True
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 163    False
# 164    False
# 165     True
# 166     True
# 167     True
# 168    False
# 169    False
# 170    False
# 171     True
# 172    False
# 173    False
# 174    False
# 175    False
# 176    False
# 177     True
# 178     True
# 179    False
# 180    False
# 181    False
# 182    False
# 183    False
# 184    False
# 185     True
# 186    False
# 187    False
# 188    False
# 189    False
# 190    False
# 191    False
# 192    False
# dtype: bool

# %%
# last 5 elements of the dataframe sorted by beer servings
drinks.sort_index(by='beer_servings').tail(6)
# note tail took in an optional input of 6, showing us the last 6 rows
# Out:
# /Users/Varun/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:2: FutureWarning: by argument to sort_index is deprecated, pls use .sort_values(by=...)
#   from ipykernel import kernelapp as app
#             country  beer_servings  spirit_servings  wine_servings  \
# 98        Lithuania            343              244             56
# 135          Poland            343              215             56
# 65          Germany            346              117            175
# 62            Gabon            347               98             59
# 45   Czech Republic            361              170            134
# 117         Namibia            376                3              1
#
#      total_litres_of_pure_alcohol continent  total_servings  beer_pct_total
# 98                           12.9        EU             643        0.533437
# 135                          10.9        EU             614        0.558632
# 65                           11.3        EU             638        0.542320
# 62                            8.9        AF             504        0.688492
# 45                           11.8        EU             665        0.542857
# 117                           6.8        AF             380        0.989474

# %%
# Quiz

# 1. List countries that drink more spirits than beer on average
drinks[drinks.spirit_servings > drinks.beer_servings].sort_index(by='beer_servings', ascending = False)

# 2. What are the top three beer drinking countries?
drinks.sort_index(by='beer_servings',ascending = False).head(3)

# 3. What are the top three beer drinking countries in Europe?
drinks[drinks['continent']=="EU"].sort_index(by='beer_servings', ascending = False).head(3)
# Out:
# /Users/Varun/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:4: FutureWarning: by argument to sort_index is deprecated, pls use .sort_values(by=...)
# /Users/Varun/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:7: FutureWarning: by argument to sort_index is deprecated, pls use .sort_values(by=...)
# /Users/Varun/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:10: FutureWarning: by argument to sort_index is deprecated, pls use .sort_values(by=...)
#             country  beer_servings  spirit_servings  wine_servings  \
# 45   Czech Republic            361              170            134
# 65          Germany            346              117            175
# 135          Poland            343              215             56
#
#      total_litres_of_pure_alcohol continent  total_servings  beer_pct_total
# 45                           11.8        EU             665        0.542857
# 65                           11.3        EU             638        0.542320
# 135                          10.9        EU             614        0.558632

# %%
# Answers below don't peak!

# %%
# 1. 
drinks['country'][drinks.spirit_servings>drinks.beer_servings]
# Out:
# 1                           Albania
# 5                 Antigua & Barbuda
# 7                           Armenia
# 10                       Azerbaijan
# 11                          Bahamas
# 12                          Bahrain
# 14                         Barbados
# 15                          Belarus
# 21               Bosnia-Herzegovina
# 25                         Bulgaria
# 30                         Cambodia
# 36                            China
# 38                          Comoros
# 40                     Cook Islands
# 43                             Cuba
# 49                         Djibouti
# 50                         Dominica
# 54                      El Salvador
# 61                           France
# 64                          Georgia
# 68                          Grenada
# 69                        Guatemala
# 71                    Guinea-Bissau
# 72                           Guyana
# 73                            Haiti
# 74                         Honduras
# 77                            India
# 82                           Israel
# 84                          Jamaica
# 85                            Japan
#                    ...
# 89                         Kiribati
# 91                       Kyrgyzstan
# 94                          Lebanon
# 96                          Liberia
# 101                          Malawi
# 112                        Mongolia
# 113                      Montenegro
# 119                           Nepal
# 122                       Nicaragua
# 125                            Niue
# 134                     Philippines
# 137                           Qatar
# 139                         Moldova
# 141              Russian Federation
# 143               St. Kitts & Nevis
# 144                       St. Lucia
# 145    St. Vincent & the Grenadines
# 149                    Saudi Arabia
# 155                        Slovakia
# 161                       Sri Lanka
# 162                           Sudan
# 163                        Suriname
# 167                           Syria
# 168                      Tajikistan
# 169                        Thailand
# 177                    Turkmenistan
# 178                          Tuvalu
# 180                         Ukraine
# 181            United Arab Emirates
# 186                      Uzbekistan
# Name: country, dtype: object

# %%
# 2. 
drinks[['country', 'beer_servings']].sort_index(by='beer_servings').tail(3)
# Out:
# /Users/sinanozdemir/anaconda/envs/sfdat26-env/lib/python2.7/site-packages/ipykernel/__main__.py:2: FutureWarning: by argument to sort_index is deprecated, pls use .sort_values(by=...)
#   from ipykernel import kernelapp as app
#             country  beer_servings
# 62            Gabon            347
# 45   Czech Republic            361
# 117         Namibia            376

# %%
# 3. 
drinks[drinks.continent=='EU'][['country', 'beer_servings']].sort_index(by='beer_servings', ascending=False).head(3)
# Out:
# /Users/sinanozdemir/anaconda/envs/sfdat26-env/lib/python2.7/site-packages/ipykernel/__main__.py:2: FutureWarning: by argument to sort_index is deprecated, pls use .sort_values(by=...)
#   from ipykernel import kernelapp as app
#             country  beer_servings
# 45   Czech Republic            361
# 65          Germany            346
# 135          Poland            343

# %%
# average North American beer consumption
'''
Note the procedure:
drinks                                          Dataframe
drinks.beer_servings                            one column (Series)
drinks.beer_servings[drinks.continent=='NA']    logical filtering
drinks.beer_servings[drinks.continent=='NA'].mean() mean of that filtered column
'''

print drinks['beer_servings'][drinks.continent=='NA'].mean()
# Out:
# 145.434782609

# %%
# average European beer consumption
drinks.beer_servings[drinks.continent=='EU'].mean()
# Out:
# 193.77777777777777

# %% [markdown]
# **Split Apply Combine**
#
# <img src="https://www.safaribooksonline.com/library/view/learning-pandas/9781783985128/graphics/5128OS_09_01.jpg">
#
# Pandas uses the "groupby" command to split apply and combine

# %%
# for each continent, calculate mean beer servings
drinks.groupby('continent').beer_servings.mean()
# Out:
# continent
# AF     61.471698
# AS     37.045455
# EU    193.777778
# NA    145.434783
# OC     89.687500
# SA    175.083333
# Name: beer_servings, dtype: float64

# %%
# for each continent, count number of occurrences
drinks.groupby('continent').continent.count()
drinks.continent.value_counts() #same thing
# Out:
# AF    53
# EU    45
# AS    44
# NA    23
# OC    16
# SA    12
# Name: continent, dtype: int64

# %%
# We can apply any function using .apply
drinks.groupby('continent').beer_servings.apply(lambda x: x.mean())    # mean
# Out:
# continent
# AF     61.471698
# AS     37.045455
# EU    193.777778
# NA    145.434783
# OC     89.687500
# SA    175.083333
# Name: beer_servings, dtype: float64

# %%
# on lambda functions:

'''
Lamda Functions are ananonymous functions

f = lambda x: x + 1   IS THE SAME AS 
def f(x): return x + 1
'''

# %%
# note x here is an entire series
drinks.groupby('continent').total_servings.apply(lambda x: x.std())     # standard deviation
# Out:
# continent
# AF    114.040622
# AS    132.630446
# EU    176.921857
# NA    134.437696
# OC    175.450848
# SA     81.923606
# Name: total_servings, dtype: float64

# %%
# for each continent, calculate the min, max, and range for total servings
print drinks.groupby('continent').total_servings.min()
print drinks.groupby('continent').total_servings.max()
# Out:
# continent
# AF      0
# AS      0
# EU      0
# NA    123
# OC      0
# SA    216
# Name: total_servings, dtype: int64
# continent
# AF    504
# AS    646
# EU    695
# NA    665
# OC    545
# SA    439
# Name: total_servings, dtype: int64

# %%
# What does this do?
drinks.groupby('continent').total_servings.apply(lambda x: x.max() - x.min())
# Out:
# continent
# AF    504
# AS    646
# EU    695
# NA    542
# OC    545
# SA    223
# Name: total_servings, dtype: int64

# %%
'''
Plotting
'''

# bar plot of number of countries in each continent
drinks.continent.value_counts().plot(kind='bar', title='Countries per Continent')
plt.xlabel('Continent')
plt.ylabel('Count')

# %%
# bar plot of average number of beer servings by continent
drinks.groupby('continent').beer_servings.mean().plot(kind='bar')

# %%
# histogram of beer servings
drinks.beer_servings.hist(bins=20)

# %%
# grouped histogram of beer servings
drinks['beer_servings'].hist(by=drinks['continent'])

# stop and think, does this make sense
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x11c0b05d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x118a69750>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x11c2881d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11c4004d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x11c482550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11c4e6310>]], dtype=object)

# %%
# same charts with the same scale for x and y axis
drinks.beer_servings.hist(by=drinks.continent, sharex=True, sharey=True)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x11c75d290>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11a50a410>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x11c039a10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11d3b6dd0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x11d43ac10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11d3db790>]], dtype=object)

# %%
# boxplot of beer servings by continent
drinks.boxplot(column='beer_servings', by='continent')

# %%
# scatterplot of beer servings versus wine servings
drinks.plot(x='beer_servings', y='wine_servings', kind='scatter', alpha=0.3)

# %%
# same scatterplot, except all European countries are colored red
colors = np.where(drinks.continent=='EU', 'r', 'b')
colors      # is a series of 'r' and 'b' that 
            # correspond to countries
# Out:
# array(['b', 'r', 'b', 'r', 'b', 'b', 'b', 'r', 'b', 'r', 'r', 'b', 'b',
#        'b', 'b', 'r', 'r', 'b', 'b', 'b', 'b', 'r', 'b', 'b', 'b', 'r',
#        'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b',
#        'b', 'b', 'b', 'r', 'b', 'r', 'r', 'b', 'b', 'r', 'b', 'b', 'b',
#        'b', 'b', 'b', 'b', 'b', 'r', 'b', 'b', 'r', 'r', 'b', 'b', 'r',
#        'r', 'b', 'r', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'r', 'r', 'b',
#        'b', 'b', 'b', 'r', 'b', 'r', 'b', 'b', 'b', 'b', 'b', 'b', 'b',
#        'b', 'b', 'r', 'b', 'b', 'b', 'b', 'r', 'r', 'b', 'b', 'b', 'b',
#        'b', 'r', 'b', 'b', 'b', 'b', 'b', 'r', 'b', 'r', 'b', 'b', 'b',
#        'b', 'b', 'b', 'r', 'b', 'b', 'b', 'b', 'b', 'r', 'b', 'b', 'b',
#        'b', 'b', 'b', 'b', 'b', 'r', 'r', 'b', 'b', 'r', 'r', 'b', 'b',
#        'b', 'b', 'b', 'b', 'r', 'b', 'b', 'b', 'r', 'b', 'b', 'b', 'r',
#        'r', 'b', 'b', 'b', 'r', 'b', 'b', 'b', 'b', 'r', 'r', 'b', 'b',
#        'b', 'r', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'r', 'b',
#        'r', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b'],
#       dtype='|S1')

# %%
'''
np.where is like a condensed if statement
it's like a list comprehension for pandas!

it will loop through drinks.continent which is a series
for each element:
    if it is "EU":
        make it 'r'
    else:
        make it 'b'

More in depth:
    drinks.continent=='EU' is a logical statement
        It will return a bunch of Trues and Falses
        and np.where makes the True ones 'r' and
        the False ones 'b'
        
        Recall logical filtering!

'''

# Side quest
np.where([True, False, False], 'a', 'b')

# 10 gold coins earned
# Out:
# array(['a', 'b', 'b'],
#       dtype='|S1')

# %%
drinks.plot(x='beer_servings', y='wine_servings', kind='scatter', c=colors)
# passing colors into the chart makes the european dots, red!

# %%
'''
----UFO data----
Scraped from: http://www.nuforc.org/webreports.html
'''
# Out:
# '\n----UFO data----\nScraped from: http://www.nuforc.org/webreports.html\n'

# %%
ufo = pd.read_csv('../data/ufo.csv')

# %%
ufo.head()              # Look at the top 5 observations
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
ufo.tail()              # Look at the bottom 5 observations
# Out:
#                City Colors Reported Shape Reported State            Time
# 80538        Neligh             NaN         CIRCLE    NE  9/4/2014 23:20
# 80539  Uhrichsville             NaN          LIGHT    OH   9/5/2014 1:14
# 80540        Tucson        RED BLUE            NaN    AZ   9/5/2014 2:40
# 80541   Orland park             RED          LIGHT    IL   9/5/2014 3:43
# 80542      Loughman             NaN          LIGHT    FL   9/5/2014 5:30

# %%
ufo['Location'] = ufo['City'] + ', ' + ufo['State']

# %%
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time  \
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00
#
#                    Location
# 0                Ithaca, NY
# 1           Willingboro, NJ
# 2               Holyoke, CO
# 3               Abilene, KS
# 4  New York Worlds Fair, NY

# %%
# rename some columns
ufo.rename(columns={'Colors Reported':'Colors', 'Shape Reported':'Shape'}, inplace=True)

# %%
ufo.head()
# Out:
#                    City Colors     Shape State             Time  \
# 0                Ithaca    NaN  TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro    NaN     OTHER    NJ  6/30/1930 20:00
# 2               Holyoke    NaN      OVAL    CO  2/15/1931 14:00
# 3               Abilene    NaN      DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair    NaN     LIGHT    NY  4/18/1933 19:00
#
#                    Location
# 0                Ithaca, NY
# 1           Willingboro, NJ
# 2               Holyoke, CO
# 3               Abilene, KS
# 4  New York Worlds Fair, NY

# %%
del ufo['City']                  # delete a column (permanently)
del ufo['State']                 # delete a column (permanently)

# %%
ufo.Shape.value_counts()                # excludes missing values
# Out:
# LIGHT        16332
# TRIANGLE      7816
# CIRCLE        7725
# FIREBALL      6249
# OTHER         5506
# SPHERE        5231
# DISK          5226
# OVAL          3721
# FORMATION     2405
# CIGAR         1983
# VARIOUS       1957
# FLASH         1329
# RECTANGLE     1295
# CYLINDER      1252
# DIAMOND       1152
# CHEVRON        940
# EGG            733
# TEARDROP       723
# CONE           310
# CROSS          241
# DELTA            7
# CRESCENT         2
# ROUND            2
# HEXAGON          1
# FLARE            1
# PYRAMID          1
# DOME             1
# Name: Shape, dtype: int64

# %%
ufo.Shape.value_counts(dropna=False)    # includes missing values
# Out:
# LIGHT        16332
# NaN           8402
# TRIANGLE      7816
# CIRCLE        7725
# FIREBALL      6249
# OTHER         5506
# SPHERE        5231
# DISK          5226
# OVAL          3721
# FORMATION     2405
# CIGAR         1983
# VARIOUS       1957
# FLASH         1329
# RECTANGLE     1295
# CYLINDER      1252
# DIAMOND       1152
# CHEVRON        940
# EGG            733
# TEARDROP       723
# CONE           310
# CROSS          241
# DELTA            7
# CRESCENT         2
# ROUND            2
# HEXAGON          1
# PYRAMID          1
# DOME             1
# FLARE            1
# Name: Shape, dtype: int64

# %%
ufo.Shape.isnull().sum() # count the missing values in the shape column
# Out:
# 8402

# %%
ufo.isnull().sum()       # returns a count of missing values in all columns
# Out:
# Colors      63509
# Shape        8402
# Time            0
# Location       47
# dtype: int64

# %%
# Shows how many rows has a not null shape AND a not null color
ufo[(ufo.Shape.notnull()) & (ufo.Colors.notnull())]
# Out:
#                       Colors      Shape              Time  \
# 12                       RED     SPHERE   6/30/1939 20:00
# 19                       RED      OTHER   4/30/1943 23:00
# 36                       RED  FORMATION    7/10/1945 1:30
# 44                     GREEN     SPHERE   6/30/1946 19:00
# 82                      BLUE    CHEVRON   7/15/1947 21:00
# 84                      BLUE       DISK    8/8/1947 22:00
# 91                       RED     SPHERE   5/10/1948 19:00
# 111                   ORANGE     CIRCLE   8/15/1949 22:00
# 129                    GREEN       DISK    6/10/1950 0:00
# 138                   ORANGE      CIGAR    7/2/1950 13:00
# 152                     BLUE       DISK    4/15/1951 0:30
# 157                    GREEN       DISK   6/15/1951 20:30
# 163                    GREEN     SPHERE    7/3/1951 12:00
# 164                     BLUE       DISK   7/10/1951 23:30
# 174                   ORANGE   TRIANGLE   4/15/1952 16:00
# 178                      RED   FIREBALL    6/1/1952 22:00
# 202                    GREEN       OVAL   7/13/1952 21:00
# 226                      RED     SPHERE    4/1/1953 18:00
# 229                   YELLOW   FIREBALL   4/15/1953 16:00
# 238                      RED   FIREBALL    6/30/1953 0:00
# 241                     BLUE       DISK    7/4/1953 14:00
# 249                   ORANGE      OTHER   8/15/1953 19:00
# 256                    GREEN       DISK  11/21/1953 22:30
# 288                      RED       OVAL    7/1/1954 21:00
# 289                      RED     CIRCLE    7/1/1954 22:00
# 304                      RED       DISK    9/9/1954 12:30
# 311                   ORANGE     CIRCLE  12/15/1954 23:10
# 314                   YELLOW        EGG    5/1/1955 15:00
# 323                   ORANGE     CIRCLE    6/15/1955 0:00
# 354                   ORANGE   CYLINDER    6/1/1956 20:00
# ...                      ...        ...               ...
# 80429                    RED     CIRCLE   8/31/2014 20:50
# 80430                    RED     SPHERE   8/31/2014 21:00
# 80436                 ORANGE     SPHERE   8/31/2014 21:45
# 80438                 ORANGE   CYLINDER   8/31/2014 22:00
# 80441                    RED   TEARDROP   8/31/2014 22:30
# 80453  RED ORANGE GREEN BLUE   TRIANGLE    9/1/2014 11:56
# 80457                 ORANGE     CIRCLE    9/1/2014 16:05
# 80458                 ORANGE   FIREBALL    9/1/2014 20:00
# 80459                 ORANGE     CIRCLE    9/1/2014 20:00
# 80465                  GREEN    VARIOUS    9/1/2014 21:30
# 80467                 ORANGE      LIGHT    9/1/2014 22:00
# 80469                 ORANGE     CIRCLE    9/1/2014 22:19
# 80473                   BLUE   TRIANGLE     9/2/2014 5:50
# 80482                 ORANGE   FIREBALL    9/2/2014 22:30
# 80489                 ORANGE     SPHERE     9/3/2014 5:00
# 80494              RED GREEN     CIRCLE    9/3/2014 19:00
# 80495                 YELLOW      FLASH    9/3/2014 19:00
# 80496                    RED      FLASH    9/3/2014 19:00
# 80500               RED BLUE      LIGHT    9/3/2014 21:00
# 80503                 ORANGE    VARIOUS    9/3/2014 21:15
# 80505                 YELLOW   TRIANGLE    9/3/2014 21:30
# 80509               RED BLUE     CIRCLE    9/3/2014 23:30
# 80510                    RED       OVAL     9/4/2014 0:00
# 80519                    RED     CIRCLE    9/4/2014 20:20
# 80522                 ORANGE      LIGHT    9/4/2014 20:30
# 80524                    RED      LIGHT    9/4/2014 21:10
# 80525                   BLUE      LIGHT    9/4/2014 21:11
# 80528                    RED   TRIANGLE    9/4/2014 21:30
# 80536                    RED       DISK    9/4/2014 23:00
# 80541                    RED      LIGHT     9/5/2014 3:43
#
#                     Location
# 12                Belton, SC
# 19            Bering Sea, AK
# 36            Portsmouth, VA
# 44             Blairsden, CA
# 82              San Jose, CA
# 84               Modesto, CA
# 91                Scipio, IN
# 111         Tarrant City, AL
# 129                 Napa, CA
# 138        Coeur d'Alene, ID
# 152               Irving, KS
# 157           Greenville, MS
# 163          Green River, WY
# 164                Provo, UT
# 174           Greenville, TX
# 178              Norfolk, VA
# 202            Arlington, VA
# 226            Cambridge, MA
# 229         Midwest City, OK
# 238            Cleveland, OH
# 241                      NaN
# 249              Artesia, NM
# 256            Pendleton, IN
# 288    St. Louis Airport, MO
# 289          Los Angeles, CA
# 304             Beaumont, TX
# 311             Red Bank, NJ
# 314             Holbrook, MA
# 323          Terre Haute, IN
# 354              Memphis, TN
# ...                      ...
# 80429         Bettendorf, IA
# 80430      Pompton Lakes, NJ
# 80436           Montrose, MI
# 80438          Brunswick, OH
# 80441           Scribner, NE
# 80453        Minersville, PA
# 80457           Syracuse, NY
# 80458              Parma, OH
# 80459            Roswell, NM
# 80465  South Londonderry, VT
# 80467          Gold Hill, NC
# 80469            Milford, DE
# 80473            Trevose, PA
# 80482          Spearfish, SD
# 80489    Pleasure Island, NC
# 80494         Boca Raton, FL
# 80495           Kingston, NH
# 80496      New York City, NY
# 80500          Johnsburg, IL
# 80503        Bethel Park, PA
# 80505           Clarence, NY
# 80509   Chesapeake Beach, MD
# 80510        Rogersville, TN
# 80519         Glen Ellyn, IL
# 80522           Lawrence, MA
# 80524            Olympia, WA
# 80525          Iowa City, IA
# 80528     North Royalton, OH
# 80536            Wyoming, PA
# 80541        Orland park, IL
#
# [15516 rows x 4 columns]

# %%
ufo.dropna()             # drop a row if ANY values are missing
print ufo.dropna().shape
ufo.dropna(how='all')    # drop a row only if ALL values are missing
print ufo.dropna(how='all').shape
# Out:
# (15510, 4)
# (80543, 4)

# %%
ufo.head()                      # Without an inplace=True, the dataframe is unaffected!
# Out:
#   Colors     Shape             Time                  Location
# 0    NaN  TRIANGLE   6/1/1930 22:00                Ithaca, NY
# 1    NaN     OTHER  6/30/1930 20:00           Willingboro, NJ
# 2    NaN      OVAL  2/15/1931 14:00               Holyoke, CO
# 3    NaN      DISK   6/1/1931 13:00               Abilene, KS
# 4    NaN     LIGHT  4/18/1933 19:00  New York Worlds Fair, NY

# %%
ufo.Colors.fillna(value='Unknown', inplace=True) # Permanent

# %%
ufo.head(10)
# Out:
#     Colors     Shape              Time                  Location
# 0  Unknown  TRIANGLE    6/1/1930 22:00                Ithaca, NY
# 1  Unknown     OTHER   6/30/1930 20:00           Willingboro, NJ
# 2  Unknown      OVAL   2/15/1931 14:00               Holyoke, CO
# 3  Unknown      DISK    6/1/1931 13:00               Abilene, KS
# 4  Unknown     LIGHT   4/18/1933 19:00  New York Worlds Fair, NY
# 5  Unknown      DISK   9/15/1934 15:30           Valley City, ND
# 6  Unknown    CIRCLE    6/15/1935 0:00           Crater Lake, CA
# 7  Unknown      DISK    7/15/1936 0:00                  Alma, MI
# 8  Unknown     CIGAR  10/15/1936 17:00               Eklutna, AK
# 9  Unknown  CYLINDER    6/15/1937 0:00               Hubbard, OR

# %%
ufo.fillna(value = 'Unknown', inplace = True)   # Permanent for the entire dataframe

# %%
''' Fun Stuff '''

ufo = pd.read_csv('../data/ufo.csv')

# Make a new month column
ufo['Month'] = ufo['Time'].apply(lambda x:int(x.split('/')[0]))

'''
the apply function applys the lambda funciton to every element in the Series
lambda x:x.split('/')[0] will take in x and split it by '/' and return the first element
so if we pass in say 9/3/2014 01:22 into the function we would get:
9                i.e. the month
'''

# similar for day
ufo['Day'] = ufo['Time'].apply(lambda x:int(x.split('/')[1]))

# for year, I need the [:4] at the end to remove the time
ufo['Year'] = ufo['Time'].apply(lambda x:int(x.split('/')[2][:4]))
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time  \
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00
#
#    Month  Day  Year
# 0      6    1  1930
# 1      6   30  1930
# 2      2   15  1931
# 3      6    1  1931
# 4      4   18  1933

# %%
sightings_per_year = ufo.groupby('Year').City.count()

sightings_per_year.plot(kind='line', 
                        color='r', 
                        linewidth=1, 
                        title='UFO Sightings by year')

# %%
# -----Analysis-----
# Clearly, Aliens love the X-Files (which came out in 1993).
# Aliens are a natural extension of the target demographic so it makes sense.

# Well hold on Sinan, the US population is always increasing
# So maybe there's a jump in population which would make sense!
# US Population data from 1930 as taken from the Census

us_population = pd.read_csv('../data/us_population.csv')
us_population.plot(x = 'Date', y = 'Population', legend = False)
# Seems like a steady increase to me..

# %%
# Plot the sightings in in July 
ufo[(ufo.Year==2014) & (ufo.Month == 7)].groupby('Day').City.count().plot(  kind='bar',
                                                        color='b', 
                                                        title='UFO Sightings in July 2014')
                                                        

# -----Analysis-----
# Aliens are love the 4th of July. The White House is still standing. Therefore
# it follows that Aliens are just here for the party.

# Well maybe it's just 2014?

# %%
# Plot multiple plots on the same plot (plots neeed to be in column format)
ufo_fourth = ufo[(ufo.Year.isin([2011, 2012, 2013, 2014])) & (ufo.Month == 7)]


# unstack will take a groupby of multiple indices and split it by column (mainly great for sub plotting)

# Hmm let's make that prettier by making it 4 seperate charts
ufo_fourth.groupby(['Year', 'Day']).City.count().unstack(0).plot(
                                        kind = 'bar',
                                        subplots=True, 
                                        figsize = (7,9))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x11fe25a50>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x1208b9390>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x12093a950>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x12099f8d0>], dtype=object)

# %%
'''
Further Exploration
'''

'''
Joining Data

MovieLens 100k data:
    main page: http://grouplens.org/datasets/movielens/
    data dictionary: http://files.grouplens.org/datasets/movielens/ml-100k-README.txt
    files: u.user, u.data, u.item
'''

# read 'u.data' into 'ratings'
r_cols = ['user_id', 'movie_id', 'rating', 'unix_timestamp']
ratings = pd.read_table('https://raw.githubusercontent.com/sinanuozdemir/sfdat26/master/data/u.data', header=None, names=r_cols, sep='\t')

# read 'u.item' into 'movies'
m_cols = ['movie_id', 'title']
movies = pd.read_table('https://raw.githubusercontent.com/sinanuozdemir/sfdat26/master/data/u.item', header=None, names=m_cols, sep='|', usecols=[0,1])

# %%
movies.head()
# Out:
#    movie_id              title
# 0         1   Toy Story (1995)
# 1         2   GoldenEye (1995)
# 2         3  Four Rooms (1995)
# 3         4  Get Shorty (1995)
# 4         5     Copycat (1995)

# %%
ratings.head()
# Out:
#    user_id  movie_id  rating  unix_timestamp
# 0      196       242       3       881250949
# 1      186       302       3       891717742
# 2       22       377       1       878887116
# 3      244        51       2       880606923
# 4      166       346       1       886397596

# %%
# merge 'movies' and 'ratings' (inner join on 'movie_id')
movie_ratings = pd.merge(movies, ratings)
movie_ratings.head()
# Out:
#    movie_id             title  user_id  rating  unix_timestamp
# 0         1  Toy Story (1995)      308       4       887736532
# 1         1  Toy Story (1995)      287       5       875334088
# 2         1  Toy Story (1995)      148       4       877019411
# 3         1  Toy Story (1995)      280       4       891700426
# 4         1  Toy Story (1995)       66       3       883601324

# %%
# for each movie, count number of ratings
movie_ratings.title.value_counts()
# Out:
# Star Wars (1977)                                      583
# Contact (1997)                                        509
# Fargo (1996)                                          508
# Return of the Jedi (1983)                             507
# Liar Liar (1997)                                      485
# English Patient, The (1996)                           481
# Scream (1996)                                         478
# Toy Story (1995)                                      452
# Air Force One (1997)                                  431
# Independence Day (ID4) (1996)                         429
# Raiders of the Lost Ark (1981)                        420
# Godfather, The (1972)                                 413
# Pulp Fiction (1994)                                   394
# Twelve Monkeys (1995)                                 392
# Silence of the Lambs, The (1991)                      390
# Jerry Maguire (1996)                                  384
# Chasing Amy (1997)                                    379
# Rock, The (1996)                                      378
# Empire Strikes Back, The (1980)                       367
# Star Trek: First Contact (1996)                       365
# Back to the Future (1985)                             350
# Titanic (1997)                                        350
# Mission: Impossible (1996)                            344
# Fugitive, The (1993)                                  336
# Indiana Jones and the Last Crusade (1989)             331
# Willy Wonka and the Chocolate Factory (1971)          326
# Princess Bride, The (1987)                            324
# Forrest Gump (1994)                                   321
# Monty Python and the Holy Grail (1974)                316
# Saint, The (1997)                                     316
#                                                      ...
# Brother's Kiss, A (1997)                                1
# Coldblooded (1995)                                      1
# Silence of the Palace, The (Saimt el Qusur) (1994)      1
# Century (1993)                                          1
# Homage (1995)                                           1
# Hana-bi (1997)                                          1
# Symphonie pastorale, La (1946)                          1
# They Made Me a Criminal (1939)                          1
# Brothers in Trouble (1995)                              1
# Girls Town (1996)                                       1
# Touki Bouki (Journey of the Hyena) (1973)               1
# Marlene Dietrich: Shadow and Light (1996)               1
# Sleepover (1995)                                        1
# Sunchaser, The (1996)                                   1
# Nothing Personal (1995)                                 1
# Niagara, Niagara (1997)                                 1
# Further Gesture, A (1996)                               1
# Great Day in Harlem, A (1994)                           1
# Eye of Vichy, The (Oeil de Vichy, L') (1993)            1
# Daens (1992)                                            1
# Woman in Question, The (1950)                           1
# Someone Else's America (1995)                           1
# Man from Down Under, The (1943)                         1
# Jupiter's Wife (1994)                                   1
# Spanish Prisoner, The (1997)                            1
# Next Step, The (1995)                                   1
# I, Worst of All (Yo, la peor de todas) (1990)           1
# Two Friends (1986)                                      1
# Gate of Heavenly Peace, The (1995)                      1
# Crude Oasis, The (1995)                                 1
# Name: title, dtype: int64

# %%
movie_ratings.groupby('title').rating.mean().order(ascending=False)
# Out:
# /Users/sinanozdemir/anaconda/envs/sfdat26-env/lib/python2.7/site-packages/ipykernel/__main__.py:1: FutureWarning: order is deprecated, use sort_values(...)
#   if __name__ == '__main__':
# title
# Marlene Dietrich: Shadow and Light (1996)                 5.000000
# Prefontaine (1997)                                        5.000000
# Santa with Muscles (1996)                                 5.000000
# Star Kid (1997)                                           5.000000
# Someone Else's America (1995)                             5.000000
# Entertaining Angels: The Dorothy Day Story (1996)         5.000000
# Saint of Fort Washington, The (1993)                      5.000000
# Great Day in Harlem, A (1994)                             5.000000
# They Made Me a Criminal (1939)                            5.000000
# Aiqing wansui (1994)                                      5.000000
# Pather Panchali (1955)                                    4.625000
# Anna (1996)                                               4.500000
# Everest (1998)                                            4.500000
# Maya Lin: A Strong Clear Vision (1994)                    4.500000
# Some Mother's Son (1996)                                  4.500000
# Close Shave, A (1995)                                     4.491071
# Schindler's List (1993)                                   4.466443
# Wrong Trousers, The (1993)                                4.466102
# Casablanca (1942)                                         4.456790
# Wallace & Gromit: The Best of Aardman Animation (1996)    4.447761
# Shawshank Redemption, The (1994)                          4.445230
# Rear Window (1954)                                        4.387560
# Usual Suspects, The (1995)                                4.385768
# Star Wars (1977)                                          4.358491
# 12 Angry Men (1957)                                       4.344000
# Third Man, The (1949)                                     4.333333
# Letter From Death Row, A (1998)                           4.333333
# Bitter Sugar (Azucar Amargo) (1996)                       4.333333
# Citizen Kane (1941)                                       4.292929
# Some Folks Call It a Sling Blade (1993)                   4.292683
#                                                             ...
# Symphonie pastorale, La (1946)                            1.000000
# Baton Rouge (1988)                                        1.000000
# Boys in Venice (1996)                                     1.000000
# Tigrero: A Film That Was Never Made (1994)                1.000000
# Office Killer (1997)                                      1.000000
# T-Men (1947)                                              1.000000
# Terror in a Texas Town (1958)                             1.000000
# Nobody Loves Me (Keiner liebt mich) (1994)                1.000000
# The Courtyard (1995)                                      1.000000
# King of New York (1990)                                   1.000000
# Liebelei (1933)                                           1.000000
# Stefano Quantestorie (1993)                               1.000000
# Hostile Intentions (1994)                                 1.000000
# Pharaoh's Army (1995)                                     1.000000
# New Age, The (1994)                                       1.000000
# Hungarian Fairy Tale, A (1987)                            1.000000
# Death in the Garden (Mort en ce jardin, La) (1956)        1.000000
# Promise, The (Versprechen, Das) (1994)                    1.000000
# I, Worst of All (Yo, la peor de todas) (1990)             1.000000
# Power 98 (1995)                                           1.000000
# Police Story 4: Project S (Chao ji ji hua) (1993)         1.000000
# Low Life, The (1994)                                      1.000000
# Somebody to Love (1994)                                   1.000000
# Invitation, The (Zaproszenie) (1986)                      1.000000
# Lotto Land (1995)                                         1.000000
# Touki Bouki (Journey of the Hyena) (1973)                 1.000000
# JLG/JLG - autoportrait de d�cembre (1994)                 1.000000
# Daens (1992)                                              1.000000
# Butterfly Kiss (1995)                                     1.000000
# Eye of Vichy, The (Oeil de Vichy, L') (1993)              1.000000
# Name: rating, dtype: float64
